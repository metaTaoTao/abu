# %% [markdown]
# ### 点击上方的运行按钮，启动回测操作界面，如下图所示：
#
# ![](./run_cell.png)

# %%
# %matplotlib inline
import widget_loop_back
widget_loop_back.show_ui()
# Out:
# VBox(children=(Tab(children=(VBox(children=(BoundedIntText(value=1000000, description='初始资金:', max=999999999, …
# 提示
# 没有添加任何一个买入策略！
# argument for 's' must be a bytes object
# Traceback (most recent call last):
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuDTUtil.py", line 164, in wrapper
#     return func(*args, **kwargs)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuOsUtil.py", line 33, in show_msg
#     do_show_msg(title, msg)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 39, in show_msg
#     MainWindow(to_native_str(title), to_native_str(msg))
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 198, in __init__
#     self.show_balloon(title, msg)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 215, in show_balloon
#     shell_notify_icon(NIM_MODIFY, nid.pack())
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 148, in pack
#     return self._struct.pack(
# struct.error: argument for 's' must be a bytes object
# 提示
# 动态双均慢动态快动态买入策略已添加成功！
# (1410, 'RegisterClass', '类已存在。')
# Traceback (most recent call last):
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuDTUtil.py", line 164, in wrapper
#     return func(*args, **kwargs)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuOsUtil.py", line 33, in show_msg
#     do_show_msg(title, msg)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 39, in show_msg
#     MainWindow(to_native_str(title), to_native_str(msg))
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 181, in __init__
#     class_atom = RegisterClass(wc)
# pywintypes.error: (1410, 'RegisterClass', '类已存在。')
# 提示
# n atr止盈3.0止损1.0000000000000002策略已添加成功！
# (1410, 'RegisterClass', '类已存在。')
# Traceback (most recent call last):
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuDTUtil.py", line 164, in wrapper
#     return func(*args, **kwargs)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuOsUtil.py", line 33, in show_msg
#     do_show_msg(title, msg)
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 39, in show_msg
#     MainWindow(to_native_str(title), to_native_str(msg))
#   File "D:\trading\VSCODE\abu\abupy\UtilBu\ABuWinUtil.py", line 181, in __init__
#     class_atom = RegisterClass(wc)
# pywintypes.error: (1410, 'RegisterClass', '类已存在。')
# Box(children=(Text(value='pid=30408 begin work'), FloatProgress(value=0.0)))
# FloatProgress(value=0.0)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:246: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:246: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:246: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:246: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:221: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\TradeBu\ABuCommission.py:246: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   self.commission_df = self.commission_df.append(record_df)
# D:\trading\VSCODE\abu\abupy\ExtBu\empyrical\stats.py:213: DeprecationWarning: The __array_wrap__ method of DataFrame and Series will be removed in a future version
#   result = wrap(result)
# 买入后卖出的交易数量:5
# 买入后尚未卖出的交易数量:0
# 胜率:20.0000%
# 平均获利期望:21.8159%
# 平均亏损期望:-11.3463%
# 盈亏比:0.4830
# 策略收益: -17.7177%
# 基准收益: 1.8196%
# 策略年化收益: -8.8588%
# 基准年化收益: 0.9098%
# 策略买入成交比例:100.0000%
# 策略资金利用率比例:14.9504%
# 策略共执行504个交易日
# 交易买卖详情单：
#             buy_date  buy_price  buy_cnt                       buy_factor  \
# 2014-11-18  20141118    257.750   2909.0    AbuDoubleMaBuy:fast=8,slow=50
# 2015-04-30  20150430    229.030   3274.0  AbuDoubleMaBuy:fast=30,slow=100
# 2015-09-18  20150918    260.660   2829.0   AbuDoubleMaBuy:fast=5,slow=100
# 2015-12-21  20151221    233.455   3212.0   AbuDoubleMaBuy:fast=24,slow=80
# 2016-06-01  20160601    219.645   3414.0    AbuDoubleMaBuy:fast=4,slow=25
#
#             symbol         buy_pos buy_type_str  expect_direction  \
# 2014-11-18  usTSLA  AbuAtrPosition         call               1.0
# 2015-04-30  usTSLA  AbuAtrPosition         call               1.0
# 2015-09-18  usTSLA  AbuAtrPosition         call               1.0
# 2015-12-21  usTSLA  AbuAtrPosition         call               1.0
# 2016-06-01  usTSLA  AbuAtrPosition         call               1.0
#
#                                            sell_type_extra  sell_date  \
# 2014-11-18  AbuFactorAtrNStop:stop_loss=1.0000000000000002   20141202
# 2015-04-30                  AbuFactorAtrNStop:stop_win=3.0   20150706
# 2015-09-18  AbuFactorAtrNStop:stop_loss=1.0000000000000002   20151008
# 2015-12-21  AbuFactorAtrNStop:stop_loss=1.0000000000000002   20160111
# 2016-06-01  AbuFactorAtrNStop:stop_loss=1.0000000000000002   20160623
#
#             sell_price sell_type ml_features  key     profit  result  \
# 2014-11-18     231.440      loss        None   83  -76535.79      -1
# 2015-04-30     278.995       win        None  194  163585.41       1
# 2015-09-18     226.015      loss        None  291  -98010.70      -1
# 2015-12-21     208.725      loss        None  356  -79432.76      -1
# 2016-06-01     194.840      loss        None  467  -84684.27      -1
#
#             profit_cg  profit_cg_hunder  keep_days
# 2014-11-18    -0.1021          -10.2076         14
# 2015-04-30     0.2182           21.8159         67
# 2015-09-18    -0.1329          -13.2913         20
# 2015-12-21    -0.1059          -10.5930         21
# 2016-06-01    -0.1129          -11.2932         22

# %% [markdown]
# [abu量化系统github地址](https://github.com/bbfamily/abu) (您的star是我的动力！)
#
# [更多阿布量化量化技术文章](http://www.abuquant.com/article)
#
# 更多关于量化交易相关请阅读[《量化交易之路》](http://www.abuquant.com/books/quantify-trading-road.html)
#
# 更多关于量化交易与机器学习相关请阅读[《机器学习之路》](http://www.abuquant.com/books/machine-learning-road.html)
#
# 更多关于abu量化系统请关注微信公众号: abu_quant
#
# ![](../abupy_lecture/image/qrcode.jpg)
